# %% [markdown]
# # Example 4: Publication-oriented fitting scaffold
#
# This is the expert path. It starts audit-only, then adds baseline fits, systematic variants, and injection/recovery only when explicitly requested.

# %%
# Audit-only command from a shell:
# python examples/example4_publication_quality_fitting.py \
#   --output-json /tmp/spyctres_example4_publication.json

# Opt-in baseline fit:
# python examples/example4_publication_quality_fitting.py \
#   --run-baseline-fit \
#   --output-json /tmp/spyctres_example4_publication_fit.json \
#   --output-plot /tmp/spyctres_example4_publication_fit.png
